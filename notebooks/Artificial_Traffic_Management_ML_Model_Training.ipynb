# %% [markdown]
# <a href="https://colab.research.google.com/github/Arup3201/AOTS/blob/main/Artificial_Traffic_Management_ML_Model_Training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
